# %%
import os
import cv2
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.models import load_model

def preprocess_image(image_path, img_size=(128, 128)):
    # Read image
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise FileNotFoundError(f"Image not found at path: {image_path}")
    # Resize image
    img = cv2.resize(img, img_size)
    # Normalize image
    img = img / 255.0
    return img

def load_data(data_dir, img_size=(128, 128)):
    images = []
    labels = []
    for label in os.listdir(data_dir):
        class_dir = os.path.join(data_dir, label)
        if os.path.isdir(class_dir):
            for img_file in os.listdir(class_dir):
                img_path = os.path.join(class_dir, img_file)
                img = preprocess_image(img_path, img_size)
                images.append(img)
                labels.append(label)
    return np.array(images), np.array(labels)

# Specify the path to your dataset directory
data_dir = '/content/drive/MyDrive/Signature_Dataset/dataset/sign_data/train'

X, y = load_data(data_dir)

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 1)),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(len(np.unique(y_encoded)), activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test), batch_size=32)

loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {accuracy * 100:.2f}%')

model.save('signature_recognition_model.h5')
model = load_model('signature_recognition_model.h5')

def predict_signature(image_path, true_label):
    img = preprocess_image(image_path)
    img = np.expand_dims(img, axis=0)
    img = np.expand_dims(img, axis=-1)  # Add the channel dimension
    prediction = model.predict(img)
    predicted_label = label_encoder.inverse_transform([np.argmax(prediction)])
    return predicted_label[0] == true_label

# Update the path to point to a specific image file and the true label of the signature
new_image_path = '/content/drive/MyDrive/Signature_Dataset/dataset/sign_data/test/049/01_049.png'
true_label = '001'  # The true label of the signature
is_genuine = predict_signature(new_image_path, true_label)
print(f'Signature is genuine: {is_genuine}')
# Out:
# Epoch 1/10
# 42/42 [==============================] - 36s 831ms/step - loss: 5.4976 - accuracy: 0.0083 - val_loss: 4.8519 - val_accuracy: 0.0091
# Epoch 2/10
# 42/42 [==============================] - 38s 901ms/step - loss: 4.8499 - accuracy: 0.0114 - val_loss: 4.8523 - val_accuracy: 0.0152
# Epoch 3/10
# 42/42 [==============================] - 33s 799ms/step - loss: 4.8481 - accuracy: 0.0099 - val_loss: 4.8526 - val_accuracy: 0.0091
# Epoch 4/10
# 42/42 [==============================] - 34s 806ms/step - loss: 4.8465 - accuracy: 0.0159 - val_loss: 4.8530 - val_accuracy: 0.0091
# Epoch 5/10
# 42/42 [==============================] - 35s 826ms/step - loss: 4.8448 - accuracy: 0.0159 - val_loss: 4.8532 - val_accuracy: 0.0091
# Epoch 6/10
# 42/42 [==============================] - 35s 829ms/step - loss: 4.8433 - accuracy: 0.0121 - val_loss: 4.8537 - val_accuracy: 0.0091
# Epoch 7/10
# 42/42 [==============================] - 35s 827ms/step - loss: 4.8418 - accuracy: 0.0159 - val_loss: 4.8539 - val_accuracy: 0.0091
# Epoch 8/10
# 42/42 [==============================] - 34s 824ms/step - loss: 4.8404 - accuracy: 0.0159 - val_loss: 4.8544 - val_accuracy: 0.0091
# Epoch 9/10
# 42/42 [==============================] - 35s 827ms/step - loss: 4.8390 - accuracy: 0.0114 - val_loss: 4.8546 - val_accuracy: 0.0091
# Epoch 10/10
# 42/42 [==============================] - 37s 885ms/step - loss: 4.8376 - accuracy: 0.0159 - val_loss: 4.8549 - val_accuracy: 0.0091
# 11/11 [==============================] - 2s 152ms/step - loss: 4.8549 - accuracy: 0.0091
# Test Accuracy: 0.91%
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 78ms/step
# Signature is genuine: False

# %%
import os
import cv2
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.models import load_model

def preprocess_image(image_path, img_size=(128, 128)):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise FileNotFoundError(f"Image not found at path: {image_path}")
    img = cv2.resize(img, img_size)
    img = img / 255.0
    return img

def load_data(data_dir, img_size=(128, 128)):
    images = []
    labels = []
    for label in os.listdir(data_dir):
        class_dir = os.path.join(data_dir, label)
        if os.path.isdir(class_dir):
            for img_file in os.listdir(class_dir):
                img_path = os.path.join(class_dir, img_file)
                img = preprocess_image(img_path, img_size)
                images.append(img)
                labels.append(label)
    return np.array(images), np.array(labels)

# Specify the path to your dataset directory
data_dir = '/content/drive/MyDrive/Signature_Dataset/dataset/sign_data/train'

X, y = load_data(data_dir)

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

print("Classes and their corresponding encoded values:")
for label, encoded in zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)):
    print(f"Class: {label}, Encoded: {encoded}")

X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 1)),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(len(np.unique(y_encoded)), activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test), batch_size=32)

loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {accuracy * 100:.2f}%')

model.save('signature_recognition_model.h5')
model = load_model('signature_recognition_model.h5')

def predict_signature(image_path, true_label):
    img = preprocess_image(image_path)
    img = np.expand_dims(img, axis=0)
    img = np.expand_dims(img, axis=-1)
    prediction = model.predict(img)
    predicted_label = label_encoder.inverse_transform([np.argmax(prediction)])

    # Debug prints to trace the problem
    print(f"Image Path: {image_path}")
    print(f"True Label: {true_label}")
    print(f"Predicted Label: {predicted_label[0]}")

    return predicted_label[0] == true_label

# Prompt user for image path and true label
new_image_path = input("Enter the path to the signature image: ")
true_label = input("Enter the true label of the signature: ")

is_genuine = predict_signature(new_image_path, true_label)
print(f'Signature is genuine: {is_genuine}')
# Out:
# Classes and their corresponding encoded values:
# Class: 001, Encoded: 0
# Class: 001_forg, Encoded: 1
# Class: 002, Encoded: 2
# Class: 002_forg, Encoded: 3
# Class: 003, Encoded: 4
# Class: 003_forg, Encoded: 5
# Class: 004, Encoded: 6
# Class: 004_forg, Encoded: 7
# Class: 006, Encoded: 8
# Class: 006_forg, Encoded: 9
# Class: 009, Encoded: 10
# Class: 009_forg, Encoded: 11
# Class: 012, Encoded: 12
# Class: 012_forg, Encoded: 13
# Class: 013, Encoded: 14
# Class: 013_forg, Encoded: 15
# Class: 014, Encoded: 16
# Class: 014_forg, Encoded: 17
# Class: 015, Encoded: 18
# Class: 015_forg, Encoded: 19
# Class: 016, Encoded: 20
# Class: 016_forg, Encoded: 21
# Class: 017, Encoded: 22
# Class: 017_forg, Encoded: 23
# Class: 018, Encoded: 24
# Class: 018_forg, Encoded: 25
# Class: 019, Encoded: 26
# Class: 019_forg, Encoded: 27
# Class: 020, Encoded: 28
# Class: 020_forg, Encoded: 29
# Class: 021, Encoded: 30
# Class: 021_forg, Encoded: 31
# Class: 022, Encoded: 32
# Class: 022_forg, Encoded: 33
# Class: 023, Encoded: 34
# Class: 023_forg, Encoded: 35
# Class: 024, Encoded: 36
# Class: 024_forg, Encoded: 37
# Class: 025, Encoded: 38
# Class: 025_forg, Encoded: 39
# Class: 026, Encoded: 40
# Class: 026_forg, Encoded: 41
# Class: 027, Encoded: 42
# Class: 027_forg, Encoded: 43
# Class: 028, Encoded: 44
# Class: 028_forg, Encoded: 45
# Class: 029, Encoded: 46
# Class: 029_forg, Encoded: 47
# Class: 030, Encoded: 48
# Class: 030_forg, Encoded: 49
# Class: 031, Encoded: 50
# Class: 031_forg, Encoded: 51
# Class: 032, Encoded: 52
# Class: 032_forg, Encoded: 53
# Class: 033, Encoded: 54
# Class: 033_forg, Encoded: 55
# Class: 034, Encoded: 56
# Class: 034_forg, Encoded: 57
# Class: 035, Encoded: 58
# Class: 035_forg, Encoded: 59
# Class: 036, Encoded: 60
# Class: 036_forg, Encoded: 61
# Class: 037, Encoded: 62
# Class: 037_forg, Encoded: 63
# Class: 038, Encoded: 64
# Class: 038_forg, Encoded: 65
# Class: 039, Encoded: 66
# Class: 039_forg, Encoded: 67
# Class: 040, Encoded: 68
# Class: 040_forg, Encoded: 69
# Class: 041, Encoded: 70
# Class: 041_forg, Encoded: 71
# Class: 042, Encoded: 72
# Class: 042_forg, Encoded: 73
# Class: 043, Encoded: 74
# Class: 043_forg, Encoded: 75
# Class: 044, Encoded: 76
# Class: 044_forg, Encoded: 77
# Class: 045, Encoded: 78
# Class: 045_forg, Encoded: 79
# Class: 046, Encoded: 80
# Class: 046_forg, Encoded: 81
# Class: 047, Encoded: 82
# Class: 047_forg, Encoded: 83
# Class: 048, Encoded: 84
# Class: 048_forg, Encoded: 85
# Class: 049, Encoded: 86
# Class: 049_forg, Encoded: 87
# Class: 050, Encoded: 88
# Class: 050_forg, Encoded: 89
# Class: 051, Encoded: 90
# Class: 051_forg, Encoded: 91
# Class: 052, Encoded: 92
# Class: 052_forg, Encoded: 93
# Class: 053, Encoded: 94
# Class: 053_forg, Encoded: 95
# Class: 054, Encoded: 96
# Class: 054_forg, Encoded: 97
# Class: 055, Encoded: 98
# Class: 055_forg, Encoded: 99
# Class: 056, Encoded: 100
# Class: 056_forg, Encoded: 101
# Class: 057, Encoded: 102
# Class: 057_forg, Encoded: 103
# Class: 058, Encoded: 104
# Class: 058_forg, Encoded: 105
# Class: 059, Encoded: 106
# Class: 059_forg, Encoded: 107
# Class: 060, Encoded: 108
# Class: 060_forg, Encoded: 109
# Class: 061, Encoded: 110
# Class: 061_forg, Encoded: 111
# Class: 062, Encoded: 112
# Class: 062_forg, Encoded: 113
# Class: 063, Encoded: 114
# Class: 063_forg, Encoded: 115
# Class: 064, Encoded: 116
# Class: 064_forg, Encoded: 117
# Class: 065, Encoded: 118
# Class: 065_forg, Encoded: 119
# Class: 066, Encoded: 120
# Class: 066_forg, Encoded: 121
# Class: 067, Encoded: 122
# Class: 067_forg, Encoded: 123
# Class: 068, Encoded: 124
# Class: 068_forg, Encoded: 125
# Class: 069, Encoded: 126
# Class: 069_forg, Encoded: 127
# Epoch 1/10
# 42/42 [==============================] - 36s 811ms/step - loss: 5.1053 - accuracy: 0.0114 - val_loss: 4.8527 - val_accuracy: 0.0091
# Epoch 2/10
# 42/42 [==============================] - 34s 820ms/step - loss: 4.8500 - accuracy: 0.0152 - val_loss: 4.8530 - val_accuracy: 0.0091
# Epoch 3/10
# 42/42 [==============================] - 35s 829ms/step - loss: 4.8482 - accuracy: 0.0167 - val_loss: 4.8532 - val_accuracy: 0.0091
# Epoch 4/10
# 42/42 [==============================] - 37s 888ms/step - loss: 4.8465 - accuracy: 0.0129 - val_loss: 4.8536 - val_accuracy: 0.0061
# Epoch 5/10
# 42/42 [==============================] - 35s 828ms/step - loss: 4.8450 - accuracy: 0.0197 - val_loss: 4.8542 - val_accuracy: 0.0061
# Epoch 6/10
# 42/42 [==============================] - 34s 815ms/step - loss: 4.8440 - accuracy: 0.0159 - val_loss: 4.8545 - val_accuracy: 0.0061
# Epoch 7/10
# 42/42 [==============================] - 37s 878ms/step - loss: 4.8412 - accuracy: 0.0167 - val_loss: 4.8552 - val_accuracy: 0.0061
# Epoch 8/10
# 42/42 [==============================] - 35s 830ms/step - loss: 4.8402 - accuracy: 0.0159 - val_loss: 4.8556 - val_accuracy: 0.0061
# Epoch 9/10
# 42/42 [==============================] - 34s 819ms/step - loss: 4.8384 - accuracy: 0.0182 - val_loss: 4.8563 - val_accuracy: 0.0061
# Epoch 10/10
# 42/42 [==============================] - 34s 824ms/step - loss: 4.8365 - accuracy: 0.0152 - val_loss: 4.8577 - val_accuracy: 0.0091
# 11/11 [==============================] - 2s 154ms/step - loss: 4.8577 - accuracy: 0.0091
# Test Accuracy: 0.91%
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Enter the path to the signature image: /content/drive/MyDrive/Signature_Dataset/dataset/sign_data/train/001/001_01.PNG
# Enter the true label of the signature: 001
# 1/1 [==============================] - 0s 132ms/step
# Image Path: /content/drive/MyDrive/Signature_Dataset/dataset/sign_data/train/001/001_01.PNG
# True Label: 001
# Predicted Label: 004
# Signature is genuine: False
